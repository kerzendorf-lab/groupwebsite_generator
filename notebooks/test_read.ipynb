# %%
# Change the working directory to the desired location
# temporary, only for local
import os
#os.chdir("/home/bumblebealu/groupwebsite_generator/")
os.chdir("/Users/harshul/website clone/harshul/test/groupwebsite_generator")
os.getcwd()
# Out:
# '/Users/harshul/website clone/harshul/test/groupwebsite_generator'

# %%
import pandas as pd
from pathlib import Path
import json

# %%
MEMBERS_DIR_PATH = Path('../group-data/members/')

# %%
member_records = []
for member_dir in MEMBERS_DIR_PATH.glob('*'):
    member_record = json.load(open(member_dir / 'info.json'))
    member_json_dir = member_dir / 'jsons'
    
    if (member_experience := (member_json_dir /  'experiences.json')).exists():
        current_position = json.load(open(member_experience))[-1]
        
    elif (member_education := (member_json_dir /  'education.json')).exists():
        current_position = json.load(open(member_education))[-1]

    elif (member_awards := (member_json_dir /  'awards.json')).exists():
        current_position = json.load(open(member_awards))[-1]
    elif (member_roles := (member_json_dir /  'roles.json')).exists():
        current_position = json.load(open(member_roles))[-1]
    elif (member_projects := (member_json_dir /  'projects.json')).exists():
        current_position = json.load(open(member_projects))[-1]   

    elif (member_website_media := (member_json_dir /  'website_media.json')).exists():
        current_position = json.load(open(member_website_media))[-1]
    elif (member_posters := (member_json_dir /  'posters.json')).exists():
        current_position = json.load(open(member_posters))[-1]
    elif (member_publications := (member_json_dir /  'publications.json')).exists():
        current_position = json.load(open(member_website_media))[-1]
    elif (member_outreach := (member_json_dir /  'outreach.json')).exists():
        current_position = json.load(open(member_outreach))[-1]


   # if current_position['institution'] != 'Michigan State University':
    #        continue
#    member_record.update(current_position)
    member_records.append(member_record)

# %%
current_position
# Out:
# {'institution': 'University of Toronto',
#  'city': 'Toronto',
#  'state': 'Ontario',
#  'country': 'Canada',
#  'degree': 'Postdoctoral Fellow',
#  'start_date': '2011-10-01',
#  'end_date': '2014-09-30'}

# %%
pd.DataFrame.from_records(member_records)
# Out:
# [{'first_name': 'Joshua',
#   'last_name': 'Shields',
#   'nick_name': 'Josh',
#   'image_path': 'media/images/josh_photo.jpg',
#   'cover_image_path': 'media/images/cover.jpg',
#   'introduction': 'Josh is a senior graduate student in astrophysics who has primarily worked on the Type Ia supernova progenitor problem. He does systematic searches of supernova remnants both inside and outside our Galaxy to identify stars that were in a binary system with the white dwarf that exploded to create the remnant. He works with large scale stellar surveys like Gaia, some of the largest ground based telescopes like the VLT, and with space based data like the HST. He uses bayesian inference techniques to learn about stellar populations and search for peculiar stars that are unexplainable by normal processes of stellar evolution. He has also recently begun working on the STARDIS code, a radiative transfer code designed to simulate light running through stellar atmospheres.',
#   'id': 'josh_shields'},
#  {'first_name': 'Anirban ',
#   'last_name': 'Dutta',
#   'nick_name': '',
#   'image_path': 'media/images/anirban_dutta.jpg',
#   'cover_image_path': 'media/images/cover.jpg',
#   'introduction': 'Hi there! This is Anirban.',
#   'id': 'anirban_dutta'},
#  {'first_name': 'Erin',
#   'last_name': 'Visser',
#   'nick_name': '',
#   'image_path': 'media/images/erin_visser_website_pic.jpg',
#   'cover_image_path': 'media/images/cover.jpg',
#   'introduction': '',
#   'id': 'erin_visser'},
#  {'first_name': 'Vicente',
#   'last_name': ' Amado Olivo',
#   'nick_name': '',
#   'image_path': 'media/images/ESD_headshot.jpg',
#   'cover_image_path': 'media/images/cover.jpg',
#   'introduction': 'I am a graduate student at Michigan State University working on computational meta-research in the Deepthought Initiative (DTI) collaboration. The DTI collaboration applies computational techniques and tools to the big data that is the literature in scientific research. Specifically, DTI focuses on understanding the astrophysics literature by leveraging machine learning. My research focuses on tracking astrophysics publications and identifying all astronomers in the global community from publications on arXiv. My work in computational meta-research has benefited from being surrounded by astrophysicists from our research group, ensuring that the tools we are researching are directly applicable to astrophysicists. ',
#   'id': 'vicente_amado'},
#  {'first_name': 'Yuki',
#   'last_name': 'Matsumura',
#   'nick_name': '',
#   'image_path': 'media/images/yuki_face.png',
#   'cover_image_path': 'media/images/cover.jpg',
#   'introduction': "Hello, I am a first-year physics graduate student at Michigan State University. I obtained my bachelor's degree in physics from California Polytechnic State University in 2022.",
#   'id': 'yuki_matsumura'},
#  {'first_name': 'Andrew',
#   'last_name': 'Fullard',
#   'nick_name': '',
#   'image_path': 'media/images/me.jpg',
#   'cover_image_path': 'media/images/cover.jpg',
#   'introduction': 'I joined the TARDIS group in 2020 and worked on gamma-ray energy deposition for the TARDIS code. I am now the Core Coordinator for TARDIS, and as of 2022 a research consultant at ICER, the MSU HPCC institute.',
#   'id': 'andrew_fullard'},
#  {'first_name': 'Isaac',
#   'last_name': 'Smith',
#   'nick_name': '',
#   'image_path': 'media/images/isaac_image.jpg',
#   'cover_image_path': 'media/images/cover.jpg',
#   'introduction': '',
#   'id': 'isaac_smith'},
#  {'first_name': 'Hayden',
#   'last_name': 'Monk',
#   'nick_name': '',
#   'image_path': 'media/images/hayden.jpg',
#   'cover_image_path': 'media/images/cover.jpg',
#   'introduction': '',
#   'id': 'hayden_monk'},
#  {'first_name': 'Atharva',
#   'last_name': 'Arya',
#   'nick_name': '',
#   'image_path': 'media/images/atharva.jpg',
#   'cover_image_path': 'media/images/cover.jpg',
#   'introduction': 'I joined TARDIS as a GSoC 2021 student and I have been contributing to TARDIS ever since. Currently I am working on mitigating sustainability and infrastructure issues at TARDIS.',
#   'id': 'atharva_arya'},
#  {'first_name': 'Richard',
#   'last_name': 'Dow',
#   'nick_name': 'Tripp',
#   'image_path': 'media/images/richard.jpg',
#   'cover_image_path': 'media/images/cover.jpg',
#   'introduction': "Hi, my name is Tripp, and I'm a computer science undergraduate student at the University of Minnesota. I'm interested in mathematical modelling, automated reasoning, and computational science.",
#   'id': 'richard_dow'},
#  {'first_name': 'Bea',
#   'last_name': 'Lu',
#   'nick_name': '',
#   'image_path': 'media/images/bea_lu.jpg',
#   'cover_image_path': 'media/images/cover.jpg',
#   'introduction': 'Hi, my name is Bea and I am currently a student at Michigan State University. My interests lie in data science and web development (I helped with this website!). I have been involved in projects that includes: analyzing astrophysics publications, creating data visualizations, text classification, and more.',
#   'id': 'bea_lu'},
#  {'first_name': 'Sona',
#   'last_name': 'Chitchyan',
#   'nick_name': '',
#   'image_path': 'media/images/sona_photo.jpg',
#   'cover_image_path': 'media/images/cover.jpg',
#   'introduction': "Sona is a Master's student in astrophysics primarily working on development of TARDIS for modeling Type IIP supernovae. She works on implementation of Non-LTE treatment and nonhomologous expansion treatment for TARDIS.",
#   'id': 'sona_chitchyan'},
#  {'first_name': 'Iliomar',
#   'last_name': 'Rodriguez-Ramos',
#   'nick_name': '',
#   'image_path': 'media/images/iliomar_ft.jpg',
#   'cover_image_path': 'media/images/cover.jpg',
#   'introduction': 'As part of the REU Summer Intership Program I am currently exploring the complex structures of ancient stars with the guidance of Wolfgang Kerzendorf and Joshua Shields, using the TARDIS open-source code to compare spectral data and to delve into the depths of these celestial wonders.',
#   'id': 'iliomar_rodriguez_ramos'},
#  {'first_name': 'Jaladh',
#   'last_name': 'Singhal',
#   'nick_name': '',
#   'image_path': 'media/images/jaladh.jpg',
#   'cover_image_path': 'media/images/cover.jpg',
#   'introduction': '',
#   'id': 'jaladh_singhal'},
#  {'first_name': 'Jack',
#   'last_name': "O'Brien",
#   'nick_name': 'Jack',
#   'image_path': 'media/images/jack.jpg',
#   'cover_image_path': 'media/images/cover.jpg',
#   'introduction': "I'm Jack O'Brien, a Graduate Student in Astrophysics at Michigan State University. My research centers around trying to understand the origins of Type Ia supernovae through backwards modeling of spectral time-series using Bayesian inference and deep learning. I'm also a senior developer for TARDIS and have been a mentor for Google Summer of Code for three years. I have a passion for teaching and mentoring, and I love to share my expertise in astrophysics, programming, and data science with students at Michigan State University. With a wide range of interests, I believe that my well-rounded background makes me an effective researcher and educator.",
#   'id': 'jack_o_brien'},
#  {'first_name': 'Template',
#   'last_name': 'Person',
#   'nick_name': '',
#   'image_path': 'media/images/newton.jpg',
#   'cover_image_path': 'media/images/cover.jpg',
#   'introduction': '',
#   'id': 'template_person'},
#  {'first_name': 'Cecelia',
#   'last_name': 'Powers',
#   'nick_name': '',
#   'image_path': '../../images/me.jpg',
#   'cover_image_path': 'media/images/cover.jpg',
#   'introduction': '',
#   'id': 'cecelia_powers'},
#  {'first_name': 'Kevin',
#   'last_name': 'Cawley',
#   'nick_name': '',
#   'image_path': 'media/images/KevinCawleyFall2022.jpg',
#   'cover_image_path': 'media/images/cover.jpg',
#   'introduction': '',
#   'id': 'kevin_cawley'},
#  {'first_name': 'Sofia',
#   'last_name': 'Biriouk',
#   'nick_name': '',
#   'image_path': 'media/images/sofia.jpg',
#   'cover_image_path': 'media/images/cover.jpg',
#   'introduction': '',
#   'id': 'sofia_biriouk'},
#  {'first_name': 'Jing',
#   'last_name': 'Lu',
#   'nick_name': '',
#   'image_path': 'media/images/jing.jpg',
#   'cover_image_path': 'media/images/cover.jpg',
#   'introduction': 'I will be joinning TARDIS group in summer 2023 and work on spectral modeling of stripped envelope supernovae.',
#   'id': 'jing_lu'},
#  {'first_name': 'Alexander',
#   'last_name': 'Grunewald',
#   'nick_name': '',
#   'image_path': 'media/images/alexander.jpg',
#   'cover_image_path': 'media/images/cover.jpg',
#   'introduction': "Alexander Grunewald is an undergraduate student at Michigan State University who is double majoring in Data Science and Statistics. His primary responsibility is to assist with the research and development of an emulator for TARDIS. Outside of school, he serves as the Vice President of MSU's AI club, where he is committed to making the use of AI more accessible to everyone.",
#   'id': 'alexander_grunewald'},
#  {'first_name': 'Harshul',
#   'last_name': 'Gupta',
#   'nick_name': '',
#   'image_path': 'media/images/harshul.jpeg',
#   'cover_image_path': 'media/images/cover.jpg',
#   'introduction': 'I am a Software Developer and a Cosmology enthusiast who likes to get involved in new researches. All my life, I’ve found comfort in science. It helps give meaning to the many things we cannot control. It brings a degree of order to the chaos that surrounds us. I am also a student of Indian Classical Music since 2012 learning flute. Flute is my way of living.I feel that its sound reaches out to the soul more directly than words. Bonsai is another thing that I love to make because they train us to be patient and serene.',
#   'id': 'harshul_gupta'},
#  {'first_name': 'Wolfgang',
#   'last_name': 'Kerzendorf',
#   'nick_name': '',
#   'introduction': "I am an astrophysicist deeply intrigued by nucleosynthesis in high-energy astrophysics transients. By studying these captivating phenomena, me and my team uncover their potential as valuable distance probes. I like to explore both nucleosynthesis and cosmic distance probes by using machine learning and statistics to reconstruct explosion from observational spectral time series. Beyond astrophysics, I am dedicated to improving the academic research landscape. As an active member of the open science community, I foster collaboration and knowledge sharing. Through computational meta-research, I utilize natural language processing and machine learning to enhance peer review, advancing its efficiency and effectiveness. Let's embark on an extraordinary journey of cosmic exploration and scientific discovery together.",
#   'image_path': 'media/images/wolfgang.jpg',
#   'cover_image_path': 'media/images/cover.jpg',
#   'id': 'wolfgang_kerzendorf'}]
