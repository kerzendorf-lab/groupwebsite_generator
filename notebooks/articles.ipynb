# %%
import json
import pandas as pd
from pathlib import Path
import shutil
import re
from datetime import datetime

# Load configuration
CONFIG_PATH = Path("..") / "config.json"
with open(CONFIG_PATH, 'r') as f:
    config = json.load(f)
CONFIG_DIR = CONFIG_PATH.parent

# Constants - resolve paths relative to config directory
GROUP_DATA_DIR = (CONFIG_DIR / config["paths"]["group_data_dir"]).resolve()
ARTICLE_DIR_PATH = (CONFIG_DIR / config["paths"]["article_dir"]).resolve()
HOSTING_PATH = (CONFIG_DIR / config["paths"]["hosting_path"]).resolve()
ARTICLE_IMAGE_DESTINATION_DIR = HOSTING_PATH / "website_files" / "images" / "article_content"

DEFAULT_COVER_IMAGE_HEIGHT = config.get("default_cover_image_height", "330px")
DEFAULT_COVER_IMAGE_WIDTH = config.get("default_cover_image_width", "520px")

# %%
# Utility function
def urlize_content(content_text, members_df, current_members_df):
    """Replace [member_id] with linked names"""
    def replace_id(match):
        id_to_fetch = match.group(1)
        if id_to_fetch in members_df.index:
            name = members_df.loc[id_to_fetch, 'full_name']
            if id_to_fetch in current_members_df.index:
                return f'<a href="../members/{id_to_fetch}/{id_to_fetch}.html" target="_blank">{name}</a>'
            return name
        return id_to_fetch.replace('_', ' ').title()

    return re.sub(r'\[(\w+)\]', replace_id, content_text)

# %%
class ArticleDataLoader:
    def __init__(self, article_dir: Path, image_dest_dir: Path, members_df: pd.DataFrame, current_members_df: pd.DataFrame, platform_filter: str = None, category_replacements: dict = None):
        self.article_dir = article_dir
        self.image_dest_dir = image_dest_dir
        self.members_df = members_df
        self.current_members_df = current_members_df
        self.platform_filter = platform_filter if platform_filter is not None else config.get("platform_filter", "kg")
        self.category_replacements = category_replacements if category_replacements is not None else config.get("category_replacements", {})

    def _copy_image(self, source_dir, image_path_str):
        """Copy image from article media to destination, return new path"""
        # Skip URLs
        if image_path_str.startswith(('http://', 'https://')):
            return image_path_str

        image_name = Path(image_path_str).name
        source = source_dir.parent / "media" / "images" / image_name
        dest = self.image_dest_dir / image_name
        dest.parent.mkdir(parents=True, exist_ok=True)
        shutil.copy2(source, dest)
        return f"website_files/images/article_content/{image_name}"

    def _process_images(self, article, source_dir):
        """Process all images in article (cover + content)"""
        if article["cover_image"]:
            article["cover_image"] = self._copy_image(source_dir, article["cover_image"])

        for key, val in article["content"].items():
            if "img" in key and val:
                article["content"][key] = self._copy_image(source_dir, val)

    def split_news_research(self):
        """Split articles into news and research dataframes"""
        is_news = (
            (self.articles_df["category"] == "News") |
            self.articles_df["tags"].apply(lambda x: "news" in x if isinstance(x, list) else False)
        )

        self.news_df = self.articles_df[is_news].sort_values("date", ascending=False)
        self.research_df = self.articles_df[~is_news].sort_values(["category", "date"], ascending=[True, False])

    def load_all_articles(self):
        """Load articles filtered by platform and date"""
        articles = []
        today = datetime.now()

        for info_json in self.article_dir.rglob('info.json'):
            article = json.loads(info_json.read_text())

            if self.platform_filter not in article["platforms"]:
                continue

            article_date = pd.to_datetime(article["date"], format="%m-%d-%Y")
            if article_date > today:
                continue

            article["date"] = article_date
            self._process_images(article, info_json)

            if article["category"] == "News" or ("news" in article["tags"]):
                for key, val in article["content"].items():
                    if "para" in key:
                        article["content"][key] = urlize_content(val, self.members_df, self.current_members_df)

            articles.append(article)

        if articles:
            self.articles_df = pd.DataFrame(articles).set_index('article_id')
            self.articles_df["cover_image_height"] = self.articles_df["cover_image_height"].fillna(DEFAULT_COVER_IMAGE_HEIGHT).replace("", DEFAULT_COVER_IMAGE_HEIGHT)
            self.articles_df["cover_image_width"] = self.articles_df["cover_image_width"].fillna(DEFAULT_COVER_IMAGE_WIDTH).replace("", DEFAULT_COVER_IMAGE_WIDTH)
            self.articles_df["category"] = self.articles_df["category"].replace(self.category_replacements)
            self.articles_df['image_name'] = self.articles_df['cover_image'].apply(lambda x: Path(x).name)
            self.split_news_research()
        else:
            self.articles_df = pd.DataFrame()
            self.news_df = pd.DataFrame()
            self.research_df = pd.DataFrame()

# %%
# Create output directory
OUTPUT_DIR = Path("output")
OUTPUT_DIR.mkdir(exist_ok=True)

# Load member data from CSVs in output directory
members_df = pd.read_csv(OUTPUT_DIR / "members.csv", index_col=0)
current_members_df = pd.read_csv(OUTPUT_DIR / "current_members.csv", index_col=0)

print(f"Loaded {len(members_df)} members")
print(f"Loaded {len(current_members_df)} current members")
# Out:
# Loaded 10 members
# Loaded 4 current members

# %%
members_df.head(3)
# Out:
#              first_name last_name                     image_path  \
# id
# abhinav_ohri    Abhinav      Ohri  media/images/abhinav_ohri.jpg
# atharva_arya    Atharva      Arya       media/images/atharva.jpg
# bea_lu              Bea        Lu        media/images/bea_lu.jpg
#
#                     cover_image_path  \
# id
# abhinav_ohri  media/images/cover.jpg
# atharva_arya  media/images/cover.jpg
# bea_lu        media/images/cover.jpg
#
#                                                    introduction     full_name  \
# id
# abhinav_ohri                         Hi there! This is Abhinav.  Abhinav Ohri
# atharva_arya  I joined TARDIS as a GSoC 2021 student and I h...  Atharva Arya
# bea_lu        Hi, my name is Bea and I am currently a studen...        Bea Lu
#
#                      github_handle                    email  \
# id
# abhinav_ohri  KasukabeDefenceForce  abhinavohri13@gmail.com
# atharva_arya          atharva-2001  aryaatharva18@gmail.com
# bea_lu                 bumblebealu         lubangji@msu.edu
#
#                                     website twitter_handle linkedin_handle  \
# id
# abhinav_ohri                            NaN            NaN             NaN
# atharva_arya  https://www.atharvaarya.tech/   2001_atharva    atharva-arya
# bea_lu                                  NaN            NaN             NaN
#
#                             orcid linkedin nick_name  \
# id
# abhinav_ohri                  NaN      NaN       NaN
# atharva_arya                  NaN      NaN       NaN
# bea_lu        0000-0002-3393-2424      NaN       NaN
#
#                            academic_role  \
# id
# abhinav_ohri  Research Software Engineer
# atharva_arya  Research Software Engineer
# bea_lu             Undergraduate Student
#
#                                       current_project_title
# id
# abhinav_ohri                                            NaN
# atharva_arya  Mitigating open science sustainability issues
# bea_lu                                                  NaN

# %%
current_members_df.head(3)
# Out:
#                                    current_role first_name     last_name  \
# wolfgang_kerzendorf         Assistant Professor   Wolfgang    Kerzendorf
# vicente_amado                  Graduate Student    Vicente   Amado Olivo
# atharva_arya         Research Software Engineer    Atharva          Arya
#
#                                         image_path        cover_image_path  \
# wolfgang_kerzendorf      media/images/wolfgang.jpg  media/images/cover.jpg
# vicente_amado        media/images/ESD_headshot.jpg  media/images/cover.jpg
# atharva_arya              media/images/atharva.jpg  media/images/cover.jpg
#
#                                                           introduction  \
# wolfgang_kerzendorf  I am an astrophysicist deeply intrigued by nuc...
# vicente_amado        I am a graduate student at Michigan State Univ...
# atharva_arya         I joined TARDIS as a GSoC 2021 student and I h...
#
#                                 full_name github_handle  \
# wolfgang_kerzendorf   Wolfgang Kerzendorf   wkerzendorf
# vicente_amado        Vicente  Amado Olivo           NaN
# atharva_arya                 Atharva Arya  atharva-2001
#
#                                        email                         website  \
# wolfgang_kerzendorf         wkerzend@msu.edu  https://wolfgangkerzendorf.com
# vicente_amado               amadovic@msu.edu                             NaN
# atharva_arya         aryaatharva18@gmail.com   https://www.atharvaarya.tech/
#
#                     twitter_handle               linkedin_handle  \
# wolfgang_kerzendorf    wkerzendorf  wolfgang-kerzendorf-598a0466
# vicente_amado           vamadolivo                           NaN
# atharva_arya          2001_atharva                  atharva-arya
#
#                                    orcid  linkedin  nick_name  \
# wolfgang_kerzendorf  0000-0002-0479-7235       NaN        NaN
# vicente_amado        0000-0003-2248-0941       NaN        NaN
# atharva_arya                         NaN       NaN        NaN
#
#                                                  current_project_title
# wolfgang_kerzendorf            Supernovae & Computational Metaresearch
# vicente_amado        Development Of A Global Registry For Peer Revi...
# atharva_arya             Mitigating open science sustainability issues

# %%
# Load articles
article_loader = ArticleDataLoader(
    ARTICLE_DIR_PATH,
    ARTICLE_IMAGE_DESTINATION_DIR,
    members_df,
    current_members_df
)
article_loader.load_all_articles()

print(f"Articles: {len(article_loader.articles_df)}")
print(f"News articles: {len(article_loader.news_df)}")
print(f"Research articles: {len(article_loader.research_df)}")
# Out:
# Articles: 12
# News articles: 8
# Research articles: 4

# %%
article_loader.articles_df.head(3)
# Out:
#                                                                           title  \
# article_id
# geonintern_international_ben  Unveiling Earth's Secrets with AI: Our Undergr...
# prur_conference               Peer Review Under Review - Workshop at Europea...
# uuraf21_poster_vicente                                           MSU UURAF 2021
#
#                                     author_id  display       date  category  \
# article_id
# geonintern_international_ben  benjamin_mellon     True 2024-03-18      News
# prur_conference                 vicente_amado     True 2023-02-12      News
# uuraf21_poster_vicente          vicente_amado     True 2021-04-19  Overview
#
#                                                      tags  platforms  \
# article_id
# geonintern_international_ben  [undergraduate, internship]  [kg, dti]
# prur_conference                 [Metascience, Conference]  [dti, kg]
# uuraf21_poster_vicente                         [research]  [kg, dti]
#
#                                                               short_description  \
# article_id
# geonintern_international_ben  This upcoming August, Benjamin Mellon and fell...
# prur_conference               DeepThought Initiative and collaborators organ...
# uuraf21_poster_vicente        Poster presentation for MSU's University Under...
#
#                                                                     cover_image  \
# article_id
# geonintern_international_ben  website_files/images/article_content/2BCAFnorw...
# prur_conference               website_files/images/article_content/img_PRUR.png
# uuraf21_poster_vicente        website_files/images/article_content/MAST_Post...
#
#                                                                         content  \
# article_id
# geonintern_international_ben  {'1_para': 'This upcoming August, Benjamin Mel...
# prur_conference               {'1_para': 'Wolfgang Kerzendorf and collaborat...
# uuraf21_poster_vicente        {'1_para': 'Abstract: The modern scientific co...
#
#                                                             people_involved_ids  \
# article_id
# geonintern_international_ben                                  [benjamin_mellon]
# prur_conference                            [vicente_amado, wolfgang_kerzendorf]
# uuraf21_poster_vicente        [vicente_amado, wolfgang_kerzendorf, jack_o_br...
#
#                                                                           links  \
# article_id
# geonintern_international_ben                                                 {}
# prur_conference               {'NASA ADS': 'https://ui.adsabs.harvard.edu/ab...
# uuraf21_poster_vicente                                                       {}
#
#                              twitter cover_image_height cover_image_width  \
# article_id
# geonintern_international_ben    None              330px             520px
# prur_conference                 None              330px             520px
# uuraf21_poster_vicente          None              330px             520px
#
#                                        image_name
# article_id
# geonintern_international_ben  2BCAFnorway_geo.jpg
# prur_conference                      img_PRUR.png
# uuraf21_poster_vicente            MAST_Poster.jpg

# %%
article_loader.news_df.head(3)
# Out:
#                                                                                 title  \
# article_id
# identify_telescope_machine_vicente   Identifying Telescope Usage in Astrophysics P...
# gracie_at_acres_msu_nsf             Our Student Gracie wins best talk at the ACRES...
# ICSSI_poster_vicente                Vicente Amado Olivo Bridges Machine Learning a...
#
#                                         author_id  display       date  \
# article_id
# identify_telescope_machine_vicente  vicente_amado     True 2024-11-12
# gracie_at_acres_msu_nsf             gracie_tvrdik     True 2024-07-30
# ICSSI_poster_vicente                vicente_amado     True 2024-07-01
#
#                                    category  \
# article_id
# identify_telescope_machine_vicente     News
# gracie_at_acres_msu_nsf                News
# ICSSI_poster_vicente                   News
#
#                                                                   tags  \
# article_id
# identify_telescope_machine_vicente               [paper, Metaresearch]
# gracie_at_acres_msu_nsf             [undergraduate, Award, conference]
# ICSSI_poster_vicente                [poster, metaresearch, conference]
#
#                                     platforms  \
# article_id
# identify_telescope_machine_vicente  [kg, dti]
# gracie_at_acres_msu_nsf             [kg, dti]
# ICSSI_poster_vicente                [kg, dti]
#
#                                                                     short_description  \
# article_id
# identify_telescope_machine_vicente  Vicente, our graduate student and collaborator...
# gracie_at_acres_msu_nsf             Gracie Tvrdik presented her research on the ev...
# ICSSI_poster_vicente                Who's Behind the Paper? Machine learning enabl...
#
#                                                                           cover_image  \
# article_id
# identify_telescope_machine_vicente  website_files/images/article_content/mastvsnom...
# gracie_at_acres_msu_nsf               website_files/images/article_content/image1.png
# ICSSI_poster_vicente                website_files/images/article_content/icssi_pos...
#
#                                                                               content  \
# article_id
# identify_telescope_machine_vicente  {'1_para': '<a href="../members/vicente_amado/...
# gracie_at_acres_msu_nsf             {'1_para': 'Gracie  Tvrdik presented her resea...
# ICSSI_poster_vicente                {'1_para': 'Our graduate student <a href="../m...
#
#                                                                   people_involved_ids  \
# article_id
# identify_telescope_machine_vicente  [josh_shields, wolfgang_kerzendorf, vicente_am...
# gracie_at_acres_msu_nsf                                                            []
# ICSSI_poster_vicente                             [vicente_amado, wolfgang_kerzendorf]
#
#                                                                                 links  \
# article_id
# identify_telescope_machine_vicente  {'full-paper': 'https://arxiv.org/abs/2411.009...
# gracie_at_acres_msu_nsf                                                            {}
# ICSSI_poster_vicente                                                               {}
#
#                                    twitter cover_image_height  \
# article_id
# identify_telescope_machine_vicente                      330px
# gracie_at_acres_msu_nsf                                 330px
# ICSSI_poster_vicente                  None              330px
#
#                                    cover_image_width         image_name
# article_id
# identify_telescope_machine_vicente             520px   mastvsnomast.png
# gracie_at_acres_msu_nsf                        520px         image1.png
# ICSSI_poster_vicente                           520px  icssi_poster.jpeg

# %%
article_loader.research_df
# Out:
#                                          title      author_id  display  \
# article_id
# midsure22_poster_bea              MIDSURE 2022         bea_lu     True
# uuraf21_poster_vicente          MSU UURAF 2021  vicente_amado     True
# dti_reviewer                      DTI Reviewer                    True
# pacmanweb               PACMan Web Application                    True
#
#                              date  category        tags  platforms  \
# article_id
# midsure22_poster_bea   2022-07-22  Overview  [research]  [kg, dti]
# uuraf21_poster_vicente 2021-04-19  Overview  [research]  [kg, dti]
# dti_reviewer           2025-06-16  Software  [research]      [dti]
# pacmanweb              2024-03-18  Software  [research]      [dti]
#
#                                                         short_description  \
# article_id
# midsure22_poster_bea    Poster presentation at the Mid-Michigan Sympos...
# uuraf21_poster_vicente  Poster presentation for MSU's University Under...
# dti_reviewer            <a href='http://31.97.40.150:3000/'>DTI Review...
# pacmanweb               Web application for PACMan a machine-learning ...
#
#                                                               cover_image  \
# article_id
# midsure22_poster_bea    website_files/images/article_content/bea_midsu...
# uuraf21_poster_vicente  website_files/images/article_content/MAST_Post...
# dti_reviewer            website_files/images/article_content/dti_revie...
# pacmanweb               website_files/images/article_content/pacmanweb...
#
#                                                                   content  \
# article_id
# midsure22_poster_bea    {'1_para': 'Abstract: Interdisciplinary scient...
# uuraf21_poster_vicente  {'1_para': 'Abstract: The modern scientific co...
# dti_reviewer            {'1_para': '<a href='http://31.97.40.150:3000/...
# pacmanweb               {'1_para': '<a href='https://github.com/spacet...
#
#                                                       people_involved_ids  \
# article_id
# midsure22_poster_bea         [bea_lu, vicente_amado, wolfgang_kerzendorf]
# uuraf21_poster_vicente  [vicente_amado, wolfgang_kerzendorf, jack_o_br...
# dti_reviewer            [abhinav_ohri, vicente_amado, wolfgang_kerzend...
# pacmanweb               [abhinav_ohri, atharva_arya, vicente_amado, wo...
#
#                                                                 links twitter  \
# article_id
# midsure22_poster_bea                                               {}    None
# uuraf21_poster_vicente                                             {}    None
# dti_reviewer            {'DTI Reviewer': 'http://31.97.40.150:3000/'}    None
# pacmanweb                                                          {}    None
#
#                        cover_image_height cover_image_width  \
# article_id
# midsure22_poster_bea                330px             520px
# uuraf21_poster_vicente              330px             520px
# dti_reviewer                        330px             520px
# pacmanweb                           330px             520px
#
#                                     image_name
# article_id
# midsure22_poster_bea    bea_midsure_poster.jpg
# uuraf21_poster_vicente         MAST_Poster.jpg
# dti_reviewer                  dti_reviewer.gif
# pacmanweb                        pacmanweb.png

# %%
# Save to CSV in output directory
article_loader.articles_df.to_csv(OUTPUT_DIR / "articles.csv")
article_loader.news_df.to_csv(OUTPUT_DIR / "news.csv")
article_loader.research_df.to_csv(OUTPUT_DIR / "research.csv")

print(f"Saved articles.csv ({len(article_loader.articles_df)} articles)")
print(f"Saved news.csv ({len(article_loader.news_df)} news articles)")
print(f"Saved research.csv ({len(article_loader.research_df)} research articles)")
# Out:
# Saved articles.csv (12 articles)
# Saved news.csv (8 news articles)
# Saved research.csv (4 research articles)
